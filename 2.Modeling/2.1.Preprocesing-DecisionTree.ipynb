# %%
import pandas as pd
import numpy as np

# %%
#prepocesing

dataResol = pd.read_csv("Total-data-resol-1y2Quinquenio.csv",index_col=0)

# %%
dataResol
# Out:
#                                                      Criterios aplicables  \
# Número de resolución
# 0064-2006/TDC-INDECOPI  la responsabilidad administrativa de Transport...
# 0071-2006/TDC-INDECOPI  El punto de partida para demostrar la existenc...
# 0142-2006/TDC-INDECOPI  Para el dictado de medidas correctivas, la aus...
# 1335-2006/TDC-INDECOPI  la causa no imputable debe ser entendida como ...
# 1428-2006/TDC.INDECOPI  al contratar unservicio de transporte de carga...
# ...                                                                   ...
# 1164-2015/SPC-INDECOPI  Como se ha desarrollado de manera clara en la ...
# 1208-2015/SPC-INDECOPI  Por consiguiente, la presunta falta de atenció...
# 1293-2015/SPC-INDECOPI  En efecto, Transportes Yanatile alegó como sus...
# 2688-2015/SPC-INDECOPI  Asimismo, la Sala comparte los fundamentos de ...
# 3676-2015/SPC-INDECOPI  Sobre el particular, cabe tener presente que e...
#
#                          Año               Categoría  \
# ...

# %%
## Obteniendo normativas

Entradas = dataResol[["Normativa sectorial aplicada", "Normativa específica", "Otras normas"]]
Salida =  dataResol[["Decisión"]]

# %%
#creando columna contador

Entradas["Count_normas"]=np.nan
# Out:
# <ipython-input-5-496ac9570886>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Entrada1["Count_norm_sec_aplic"]=np.nan
# <ipython-input-5-496ac9570886>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Entrada2["Count_norm_espec"]=np.nan
# <ipython-input-5-496ac9570886>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#añadiendo contador 1 si aparece noNa

Entrada1.loc[Entrada1["Normativa sectorial aplicada"].notna(),"Count_norm_sec_aplic"] = 1
Entrada2.loc[Entrada2["Normativa específica"].notna(),"Count_norm_espec"] = 1
Entrada3.loc[Entrada3["Otras normas"].notna(),"Count_otras_normas"] = 1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#añadiendo contador 0 si aparece naa

Entrada1.loc[Entrada1["Normativa sectorial aplicada"].isna(),"Count_norm_sec_aplic"] = 0
Entrada2.loc[Entrada2["Normativa específica"].isna(),"Count_norm_espec"] = 0
Entrada3.loc[Entrada3["Otras normas"].isna(),"Count_otras_normas"] = 0

# %%
###### NORMATIVA ESPECIFICA ####

# %%
Normativa_especifica_pivot = pd.pivot_table(Entrada2,
              index=["Número de resolución"],
              columns=["Normativa específica"],
              values=["Count_norm_espec"])

# %%
Normativa_especifica_pivot=Normativa_especifica_pivot.replace(np.nan,0)

# %%
Normativa_especifica_pivot = Normativa_especifica_pivot.astype(int)

# %%
### NORMATIVA SECTORIAL#####

# %%
Normativa_sectorial_pivot = pd.pivot_table(Entrada1,
              index=["Número de resolución"],
              columns=["Normativa sectorial aplicada"],
              values=["Count_norm_sec_aplic"])

# %%
#quitar nulos por 0
Normativa_sectorial_pivot=Normativa_sectorial_pivot.replace(np.nan,0)

# %%
#volver int los valores
Normativa_sectorial_pivot = Normativa_sectorial_pivot.astype(int)

# %%
###### OTRAS NORMAS ####

# %%
Otras_normas_pivot = pd.pivot_table(Entrada3,
              index=["Número de resolución"],
              columns=["Otras normas"],
              values=["Count_otras_normas"])

# %%
Otras_normas_pivot=Otras_normas_pivot.replace(np.nan,0)

# %%
Otras_normas_pivot = Otras_normas_pivot.astype(int)

# %%
#### TODAS NORMAS ####

# %%
Toda_normativa = pd.concat([Normativa_sectorial_pivot, 
                       Normativa_especifica_pivot,
                       Otras_normas_pivot], axis=1, sort=False)

# %%
Toda_normativa=Toda_normativa.replace(np.nan,0)

# %%
Toda_normativa = Toda_normativa.astype(int)

# %%
Toda_normativa
# Out:
#                              Count_norm_sec_aplic  \
# Normativa sectorial aplicada                    0
# 0004-2014/SPC-INDECOPI                          1
# 0013-2007/TDC.INDECOPI                          0
# 0039-2015/SPC-INDECOPI                          0
# 0060-2013/SPC-INDECOPI                          0
# 0064-2006/TDC-INDECOPI                          0
# ...                                           ...
# 500-2014/SPC-INDECOPI                           0
# 762-2012/SC2-INDECOPI                           0
# 821-2012/SC2-INDECOPI                           0
# 859-2012/SC2-INDECOPI                           0
# 890-2012/SC2-INDECOPI                           0
#
#                                                                             \
# Normativa sectorial aplicada Código de Protección y Defensa del Consumidor
# 0004-2014/SPC-INDECOPI                                                   0
# 0013-2007/TDC.INDECOPI                                                   0
# ...

# %%
#Toda_normativa.to_csv("Toda-normativa-para-arbol.csv")
